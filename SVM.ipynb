# %% [markdown]
# <a href="https://colab.research.google.com/github/Ru1chi/First-Project/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear SVM-classify dataset in 2 classes by just drawing 1 line
#non-linear svm-cant classify by just drawing strainght line
#kernel function-takes low dimensional i/p and transform it into a higher-dimensional space(converts non-seperable problem into seperable problem)
import pandas as pd

# %%
df=pd.read_csv("/content/iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
x=df.iloc[:,0:4]

# %%
y=df.iloc[:,4]

# %%
x
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#now import svm model
from sklearn.svm import SVC

# %%
model=SVC(kernel = 'linear')

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model.predict(x_test)
# Out:
# array(['Virginica', 'Setosa', 'Versicolor', 'Virginica', 'Versicolor',
#        'Virginica', 'Virginica', 'Versicolor', 'Versicolor', 'Setosa',
#        'Setosa', 'Versicolor', 'Virginica', 'Versicolor', 'Versicolor',
#        'Virginica', 'Setosa', 'Setosa', 'Versicolor', 'Setosa',
#        'Versicolor', 'Virginica', 'Virginica', 'Setosa', 'Versicolor',
#        'Setosa', 'Setosa', 'Setosa', 'Setosa', 'Virginica'], dtype=object)

# %%
x_test
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 129           7.2          3.0           5.8          1.6
# 15            5.7          4.4           1.5          0.4
# 73            6.1          2.8           4.7          1.2
# 107           7.3          2.9           6.3          1.8
# 82            5.8          2.7           3.9          1.2
# 134           6.1          2.6           5.6          1.4
# 120           6.9          3.2           5.7          2.3
# 55            5.7          2.8           4.5          1.3
# 63            6.1          2.9           4.7          1.4
# 41            4.5          2.3           1.3          0.3
# 1             4.9          3.0           1.4          0.2
# 93            5.0          2.3           3.3          1.0
# 127           6.1          3.0           4.9          1.8
# 97            6.2          2.9           4.3          1.3
# 56            6.3          3.3           4.7          1.6
# ...

# %%
model.score(x_test,y_test)
# Out:
# 1.0
